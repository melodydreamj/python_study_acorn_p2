# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %% [markdown]
# # Q)"12_2013_movies.csv" 파일을 데이터 프레임으로 불러오기

# %%
## Load movies data

# %% [markdown]
# # Q)domestic total gross 를 시간의 변화에 따라 그래프로 그리기
# 참고) DateTime Format의 변환의 경우에는 간단하게 pandas에서 제공하는 것 사용하기
# movies['ReleaseDate'] = pd.to_datetime(movies['ReleaseDate'])

# %% [markdown]
# # Q) runtime vs. domestic total gross 에 해당하는 scatter 그래프를 그리시오

# %% [markdown]
# # Q)  Rating을 기준으로 groupby를 수행하고, Rating의 구성요소별로 Runtime의 평균과 DomesticTotalGross 의 평균을 구하여라

# %%
# Out:
#            Runtime  DomesticTotalGross
# Rating
# G       107.000000        2.684928e+08
# PG       99.933333        1.311357e+08
# PG-13   117.510638        1.114498e+08
# R       110.729730        6.989243e+07

# %% [markdown]
# # Q) Rating 값의 종류에 따라서 각기 subplot을 그리시오.
# # 각기 subplot의 가로 : release date, 세로 : domesticTotal Gross

# %%
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x117e8b190>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x118274a50>], dtype=object)

# %% [markdown]
# # Q) 감독을 찾아라
# 감독들이 여러 작품을 작업한 경우가 있는데, 여러 작업을 한 경우에는 각 작업당 평균 domestictotalgross를 구해서, 누가 제일 domestic total gross 평균이 높은지 찾으세요
# Answer : Spike Jonze

# %%
# Out:
#                           Budget  DomesticTotalGross  Runtime
# Director
# Spike Jonze           23000000.0          25568251.0    120.0
# Jon LucasScott Moore  13000000.0          25682380.0     93.0
# Edgar Wright          20000000.0          26004851.0    109.0
# Andrew Niccol         40000000.0          26627201.0    125.0
# Ron Howard            38000000.0          26947624.0    123.0

# %% [markdown]
# # Q) 2013년 "월"별 "Domestic Total Gross"의 평균과 표준편차가 있는 그래프를 그리시오
# ref) 그래프 모양 : http://matplotlib.org/examples/pylab_examples/barchart_demo.html
#
# ref) groupby하고 중간에 빠진 데이터를 잘 처리해주는 pandas.Grouper가 있음.
#
# movies.groupby(pd.Grouper(key = 'ReleaseDate', freq='M'))['DomesticTotalGross']
#
# ref) std : Compute standard deviation of groups, excluding missing values
# ref) datetime형식을 "월"의 이름으로 변경하는 옵션 : datetime.strftime("%B") --> 2013-01-31 00:00:00 -> January, 2013-02-28 00:00:00 -> February
